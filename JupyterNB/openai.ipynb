# %%
from openai import OpenAI
import os
from dotenv import load_dotenv
from rich import print as rprint

# Load the environment variables from .env file
load_dotenv()

api_key = os.getenv('OPENAI_API_KEY')

client = OpenAI(
  api_key=os.environ['OPENAI_API_KEY'],  # this is also the default, it can be omitted
)

print(f"Secret Key: {api_key}")
# Out:
# Secret Key: sk-proj-G4skwKm5bmszDdtjuCqqT3BlbkFJALZROtX1mLP23FfpsYY9

# %%
completion = client.chat.completions.create(
  model="gpt-4",
  messages=[
    {"role": "system", "content": "You are a poetic assistant, skilled in explaining complex programming concepts with creative flair."},
    {"role": "user", "content": "Compose a poem that explains the concept of recursion in programming."}
  ]
)

rprint(completion.choices[0].message)
# Out:
# ChatCompletionMessage(
#     content="In the realm of loops and function calls,\nRecursion marks the fortress's walls,\nA concept pure, like
# mirrored halls,\nProgramming's mystical crystal ball.\n\nA function calls itself, you see,\nIn a repeating,
# circular decree,\nSolving problems mathematically,\nWith elegance and symmetry.\n\nA base case first to mark the
# end,\nThen forward on our quest we send,\nTo call our function once again,\nLike a letter to a distant
# friend.\n\nIn its simplicity, it spirals down,\nThrough layers of code, to the ground,\nSolving puzzles, round and
# round,\n'Til the solution's finally found.\n\nBut embrace with care this potent power,\nFor too deep a dive could
# make the hours,\nSlip away in recursive towers,\nBlossoming like digital flowers.\n\nYet used with caution, it's a
# tool,\nThat can make complex algorithms cool,\nTurning arduous tasks to achievable rule,\nIn the vast coding
# pool.\n\nRecursion, with your Chinese box,\nYour infinite, reflective, paradox,\nYou break problems into simple
# locks,\nIn the grand coder's workshop of clocks.",
#     role='assistant',
#     function_call=None,
#     tool_calls=None
# )
