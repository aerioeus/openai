# %%
from openai import OpenAI
import os
from dotenv import load_dotenv
from rich import print as rprint
from rich.text import Text

# Load the environment variables from .env file
load_dotenv()

api_key = os.getenv('OPENAI_API_KEY')

client = OpenAI(
  api_key=os.environ['OPENAI_API_KEY'],  # this is also the default, it can be omitted
)

print(f"Secret Key: {api_key}")
# Out:
# Secret Key: sk-proj-G4skwKm5bmszDdtjuCqqT3BlbkFJALZROtX1mLP23FfpsYY9

# %%
completion = client.chat.completions.create(
  model="gpt-4o",
  messages=[
    {"role": "system", "content": "You are a poetic assistant, skilled in explaining complex programming concepts with creative flair."},
    {"role": "user", "content": "Compose a poem that explains the concept of recursion in programming."}
  ]
)

poem_text = completion.choices[0].message

rprint(poem_text)

poem = completion.choices[0].message.content

rprint(poem)
# Out:
# ChatCompletionMessage(
#     content="In a digital realm where logic weaves,\nLies recursion, a tale that never leaves.\nA function bold,
# both proud and wise,\nCalls to itself, a clever disguise.\n\nA journey within, a loop it forms,\nThrough layers and
# depths, it bravely storms.\nA task it takes, in pieces so small,\nUntil the simplest, it faces them all.\n\nOnce
# reached the base, the simplest case,\nIt halts progression, slows its pace.\nThen backward it treads, its work
# complete,\nEach step resolved, no code repeat.\n\nA fractal whisper, a spiral dance,\nEfficiency given another
# chance.\nThrough recursion’s lens, complexities fade,\nElegant solutions seamlessly made.\n\nJust like the branches
# of a tree,\nOr waves repeating endlessly,\nRecursion mirrors nature’s grace,\nA recursive call, an endless
# chase.\n\nSo when problems vast seem to confound,\nIn recursion's arms, solutions are found.\nA call to itself, a
# loop so tight,\nSolves mysteries in the code-filled night.",
#     role='assistant',
#     function_call=None,
#     tool_calls=None
# )
# In a digital realm where logic weaves,
# Lies recursion, a tale that never leaves.
# A function bold, both proud and wise,
# Calls to itself, a clever disguise.
#
# A journey within, a loop it forms,
# Through layers and depths, it bravely storms.
# A task it takes, in pieces so small,
# Until the simplest, it faces them all.
#
# Once reached the base, the simplest case,
# It halts progression, slows its pace.
# Then backward it treads, its work complete,
# Each step resolved, no code repeat.
#
# A fractal whisper, a spiral dance,
# Efficiency given another chance.
# Through recursion’s lens, complexities fade,
# Elegant solutions seamlessly made.
#
# Just like the branches of a tree,
# Or waves repeating endlessly,
# Recursion mirrors nature’s grace,
# A recursive call, an endless chase.
#
# So when problems vast seem to confound,
# In recursion's arms, solutions are found.
# A call to itself, a loop so tight,
# Solves mysteries in the code-filled night.

# %%
import speech_recognition as sr
import pyttsx3

def recognize_speech_from_mic():
    """Capture speech from the microphone and return it as text."""
    recognizer = sr.Recognizer()
    microphone = sr.Microphone()

    with microphone as source:
        recognizer.adjust_for_ambient_noise(source)
        print("Listening...")
        audio = recognizer.listen(source)

    try:
        print("Recognizing...")
        text = recognizer.recognize_google(audio)
        print(f"You said: {text}")
        return text
    except sr.RequestError:
        print("API unavailable/unresponsive")
    except sr.UnknownValueError:
        print("Unable to recognize speech")
    return ""
